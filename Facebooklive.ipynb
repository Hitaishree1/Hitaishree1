# %% [markdown]
# <a href="https://colab.research.google.com/github/Hitaishree1/Hitaishree1/blob/main/Facebooklive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("/content/Live.csv")

# %%
data
# Out:
#                               status_id status_type status_published  \
# 0      246675545449582_1649696485147474       video   4/22/2018 6:00
# 1      246675545449582_1649426988507757       photo  4/21/2018 22:45
# 2      246675545449582_1648730588577397       video   4/21/2018 6:17
# 3      246675545449582_1648576705259452       photo   4/21/2018 2:29
# 4      246675545449582_1645700502213739       photo   4/18/2018 3:22
# ...                                 ...         ...              ...
# 7045  1050855161656896_1061863470556065       photo   9/24/2016 2:58
# 7046  1050855161656896_1061334757275603       photo  9/23/2016 11:19
# 7047  1050855161656896_1060126464063099       photo  9/21/2016 23:03
# 7048  1050855161656896_1058663487542730       photo   9/20/2016 0:43
# 7049  1050855161656896_1050858841656528       photo  9/10/2016 10:30
#
#       num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# ...

# %%
data.head(20)
# Out:
#                            status_id status_type status_published  \
# 0   246675545449582_1649696485147474       video   4/22/2018 6:00
# 1   246675545449582_1649426988507757       photo  4/21/2018 22:45
# 2   246675545449582_1648730588577397       video   4/21/2018 6:17
# 3   246675545449582_1648576705259452       photo   4/21/2018 2:29
# 4   246675545449582_1645700502213739       photo   4/18/2018 3:22
# 5   246675545449582_1645650162218773       photo   4/18/2018 2:14
# 6   246675545449582_1645564175560705       video   4/18/2018 0:24
# 7   246675545449582_1644824665634656       video   4/17/2018 7:42
# 8   246675545449582_1644655795651543       photo   4/17/2018 3:33
# 9   246675545449582_1638788379571618       photo   4/11/2018 4:53
# 10  246675545449582_1637655039684952       photo   4/10/2018 1:01
# 11  246675545449582_1636730006444122       photo    4/9/2018 2:06
# 12  246675545449582_1635846033199186       photo    4/8/2018 5:10
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7050 entries, 0 to 7049
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   status_id         7050 non-null   object
#  1   status_type       7050 non-null   object
#  2   status_published  7050 non-null   object
#  3   num_reactions     7050 non-null   int64
#  4   num_comments      7050 non-null   int64
#  5   num_shares        7050 non-null   int64
#  6   num_likes         7050 non-null   int64
#  7   num_loves         7050 non-null   int64
#  8   num_wows          7050 non-null   int64
#  9   num_hahas         7050 non-null   int64
#  10  num_sads          7050 non-null   int64
#  11  num_angrys        7050 non-null   int64
#  12  Column1           0 non-null      float64
#  13  Column2           0 non-null      float64
#  14  Column3           0 non-null      float64
#  15  Column4           0 non-null      float64
# ...

# %%
data=data.drop(columns=["status_id"],axis=1)

# %%
data=data.drop(columns=["Column2","Column3","Column4"],axis=1)

# %%
data['status_date'] = pd.to_datetime(data['status_published']).dt.date

# %%
data["status_time"] = pd.to_datetime(data["status_published"]).dt.time

# %%
data.head(5)
# Out:
#   status_type status_published  num_reactions  num_comments  num_shares  \
# 0       video   4/22/2018 6:00            529           512         262
# 1       photo  4/21/2018 22:45            150             0           0
# 2       video   4/21/2018 6:17            227           236          57
# 3       photo   4/21/2018 2:29            111             0           0
# 4       photo   4/18/2018 3:22            213             0           0
#
#    num_likes  num_loves  num_wows  num_hahas  num_sads  num_angrys  Column1  \
# 0        432         92         3          1         1           0      NaN
# 1        150          0         0          0         0           0      NaN
# 2        204         21         1          1         0           0      NaN
# 3        111          0         0          0         0           0      NaN
# 4        204          9         0          0         0           0      NaN
#
#   status_date status_time
# 0  2018-04-22    06:00:00
# ...

# %%
data=data.drop(columns=["Column1","status_published"],axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7050 entries, 0 to 7049
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   status_type    7050 non-null   object
#  1   num_reactions  7050 non-null   int64
#  2   num_comments   7050 non-null   int64
#  3   num_shares     7050 non-null   int64
#  4   num_likes      7050 non-null   int64
#  5   num_loves      7050 non-null   int64
#  6   num_wows       7050 non-null   int64
#  7   num_hahas      7050 non-null   int64
#  8   num_sads       7050 non-null   int64
#  9   num_angrys     7050 non-null   int64
#  10  status_date    7050 non-null   object
#  11  status_time    7050 non-null   object
# dtypes: int64(9), object(3)
# memory usage: 661.1+ KB

# %%
data.head(5)
# Out:
#   status_type  num_reactions  num_comments  num_shares  num_likes  num_loves  \
# 0       video            529           512         262        432         92
# 1       photo            150             0           0        150          0
# 2       video            227           236          57        204         21
# 3       photo            111             0           0        111          0
# 4       photo            213             0           0        204          9
#
#    num_wows  num_hahas  num_sads  num_angrys status_date status_time
# 0         3          1         1           0  2018-04-22    06:00:00
# 1         0          0         0           0  2018-04-21    22:45:00
# 2         1          1         0           0  2018-04-21    06:17:00
# 3         0          0         0           0  2018-04-21    02:29:00
# 4         0          0         0           0  2018-04-18    03:22:00

# %%
data['status_date'] = data['status_date'].astype(str).str.replace('-', '')

# %%
data['status_date'] = data['status_date'].astype(int)

# %%
data['status_time'] = data['status_time'].astype(str).str.replace(":","")

# %%
data['status_time'] = data['status_time'].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7050 entries, 0 to 7049
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   status_type    7050 non-null   object
#  1   num_reactions  7050 non-null   int64
#  2   num_comments   7050 non-null   int64
#  3   num_shares     7050 non-null   int64
#  4   num_likes      7050 non-null   int64
#  5   num_loves      7050 non-null   int64
#  6   num_wows       7050 non-null   int64
#  7   num_hahas      7050 non-null   int64
#  8   num_sads       7050 non-null   int64
#  9   num_angrys     7050 non-null   int64
#  10  status_date    7050 non-null   int64
#  11  status_time    7050 non-null   int64
# dtypes: int64(11), object(1)
# memory usage: 661.1+ KB

# %%
import seaborn as sns

# %%
sns.heatmap(data.corr(),cmap="rainbow",annot=True)
# Out:
# <ipython-input-20-1ecac9024075>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),cmap="rainbow",annot=True)
# <Axes: >

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7050 entries, 0 to 7049
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   status_type    7050 non-null   object
#  1   num_reactions  7050 non-null   int64
#  2   num_comments   7050 non-null   int64
#  3   num_shares     7050 non-null   int64
#  4   num_likes      7050 non-null   int64
#  5   num_loves      7050 non-null   int64
#  6   num_wows       7050 non-null   int64
#  7   num_hahas      7050 non-null   int64
#  8   num_sads       7050 non-null   int64
#  9   num_angrys     7050 non-null   int64
#  10  status_date    7050 non-null   int64
#  11  status_time    7050 non-null   int64
# dtypes: int64(11), object(1)
# memory usage: 661.1+ KB

# %%
data=data.drop(columns=["status_date","status_time"],axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7050 entries, 0 to 7049
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   status_type    7050 non-null   object
#  1   num_reactions  7050 non-null   int64
#  2   num_comments   7050 non-null   int64
#  3   num_shares     7050 non-null   int64
#  4   num_likes      7050 non-null   int64
#  5   num_loves      7050 non-null   int64
#  6   num_wows       7050 non-null   int64
#  7   num_hahas      7050 non-null   int64
#  8   num_sads       7050 non-null   int64
#  9   num_angrys     7050 non-null   int64
# dtypes: int64(9), object(1)
# memory usage: 550.9+ KB

# %%
dt=data.copy()

# %%
status=dt.pop("status_type")

# %%
dt.head(4)
# Out:
#    num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 0            529           512         262        432         92         3
# 1            150             0           0        150          0         0
# 2            227           236          57        204         21         1
# 3            111             0           0        111          0         0
#
#    num_hahas  num_sads  num_angrys
# 0          1         1           0
# 1          0         0           0
# 2          1         0           0
# 3          0         0           0

# %%
status.head(3)
# Out:
# 0    video
# 1    photo
# 2    video
# Name: status_type, dtype: object

# %%
import sklearn
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
df_scaled=scaler.fit_transform(dt)
df_scaled
# Out:
# array([[ 0.64610394,  0.32335035,  1.6868788 , ...,  0.07671305,
#          0.47357035, -0.15574803],
#        [-0.17319166, -0.25220622, -0.3041444 , ..., -0.17600986,
#         -0.152587  , -0.15574803],
#        [-0.00673846,  0.01308938,  0.12901714, ...,  0.07671305,
#         -0.152587  , -0.15574803],
#        ...,
#        [-0.49312768, -0.25220622, -0.3041444 , ..., -0.17600986,
#         -0.152587  , -0.15574803],
#        [ 0.26131603, -0.23871662, -0.13695924, ..., -0.17600986,
#         -0.152587  , -0.15574803],
#        [-0.46070173, -0.25220622, -0.3041444 , ..., -0.17600986,
#         -0.152587  , -0.15574803]])

# %%
dt.columns
# Out:
# Index(['num_reactions', 'num_comments', 'num_shares', 'num_likes', 'num_loves',
#        'num_wows', 'num_hahas', 'num_sads', 'num_angrys'],
#       dtype='object')

# %%
df=pd.DataFrame(df_scaled,columns=['num_reactions', 'num_comments', 'num_shares', 'num_likes', 'num_loves',
       'num_wows', 'num_hahas', 'num_sads', 'num_angrys'])
df.head()
# Out:
#    num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 0       0.646104      0.323350    1.686879   0.482727   1.983266  0.196196
# 1      -0.173192     -0.252206   -0.304144  -0.144720  -0.318454 -0.147879
# 2      -0.006738      0.013089    0.129017  -0.024571   0.206938 -0.033187
# 3      -0.257499     -0.252206   -0.304144  -0.231495  -0.318454 -0.147879
# 4      -0.037003     -0.252206   -0.304144  -0.024571  -0.093286 -0.147879
#
#    num_hahas  num_sads  num_angrys
# 0   0.076713  0.473570   -0.155748
# 1  -0.176010 -0.152587   -0.155748
# 2   0.076713 -0.152587   -0.155748
# 3  -0.176010 -0.152587   -0.155748
# 4  -0.176010 -0.152587   -0.155748

# %%
from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import dendrogram

# %%
plt.figure(figsize=(20,10))
mergings=linkage(df,method="complete",metric="euclidean")
dendrogram(mergings)
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.cluster import KMeans

# %%
wcss=[]

for k in range(1,11):
  kmeans=KMeans(n_clusters=k,init='k-means++',max_iter=300,n_init=10,random_state=0)
  kmeans.fit(df)
  wcss.append(kmeans.inertia_)

# %%
wcss
# Out:
# [63449.999999999796,
#  48278.09824220544,
#  38372.997723869565,
#  32469.791362309865,
#  28708.85297749524,
#  25311.11678169921,
#  22132.360977241893,
#  19296.675136134138,
#  17579.616928281197,
#  16223.17202873443]

# %%
plt.figure(figsize=(5,5))
plt.plot(range(1,11),wcss,marker='o',linestyle='-',color='b')
plt.title('Elbow Method for optimal k')
plt.xlabel('Number of Cluster (K)')
plt.ylabel('withon-cluster sum of square( WCSSS)')
plt.grid(True)
plt.show()

# %%
df.columns
# Out:
# Index(['num_reactions', 'num_comments', 'num_shares', 'num_likes', 'num_loves',
#        'num_wows', 'num_hahas', 'num_sads', 'num_angrys'],
#       dtype='object')

# %%
from scipy.cluster.hierarchy import cut_tree

# %%
cluster_label=cut_tree(mergings,n_clusters=4).reshape(-1,)
cluster_label
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
dc=data.copy()
dc.head()
dc["cluster_labels"]=cluster_label
dc.head()
# Out:
#   status_type  num_reactions  num_comments  num_shares  num_likes  num_loves  \
# 0       video            529           512         262        432         92
# 1       photo            150             0           0        150          0
# 2       video            227           236          57        204         21
# 3       photo            111             0           0        111          0
# 4       photo            213             0           0        204          9
#
#    num_wows  num_hahas  num_sads  num_angrys  cluster_labels
# 0         3          1         1           0               0
# 1         0          0         0           0               0
# 2         1          1         0           0               0
# 3         0          0         0           0               0
# 4         0          0         0           0               0

# %%
dc[dc['cluster_labels']==1].sort_values(by=['num_reactions','num_comments','num_shares'],ascending=[True,False,False]).head()
# Out:
#      status_type  num_reactions  num_comments  num_shares  num_likes  \
# 3313       photo            215            44           0        176
# 6204       photo            251            29           5        228
# 6255       photo            251            29           5        228
#
#       num_loves  num_wows  num_hahas  num_sads  num_angrys  cluster_labels
# 3313          1         3          4         0          31               1
# 6204          0         3          0         1          19               1
# 6255          0         3          0         1          19               1

# %%
dc[dc['cluster_labels']==0].sort_values(by=['num_reactions','num_comments','num_shares'],ascending=[True,False,False]).head()
# Out:
#      status_type  num_reactions  num_comments  num_shares  num_likes  \
# 4332       video              0             1           0          0
# 699        photo              0             0           1          0
# 715        photo              0             0           1          0
# 2164       photo              0             0           1          0
# 4132       video              0             0           1          0
#
#       num_loves  num_wows  num_hahas  num_sads  num_angrys  cluster_labels
# 4332          0         0          0         0           0               0
# 699           0         0          0         0           0               0
# 715           0         0          0         0           0               0
# 2164          0         0          0         0           0               0
# 4132          0         0          0         0           0               0

# %%
dc[dc['cluster_labels']==2].sort_values(by=['num_reactions','num_comments','num_shares'],ascending=[True,False,False]).head()
# Out:
#      status_type  num_reactions  num_comments  num_shares  num_likes  \
# 3907       photo            391             8          48        278
# 3868       video            509            17         131        386
# 4647       video           1168          1245         358        906
# 4542       video           1611          2314        1041       1139
# 4535       video           1758          1890         718       1181
#
#       num_loves  num_wows  num_hahas  num_sads  num_angrys  cluster_labels
# 3907          0        13         97         1           2               2
# 3868          3        18        102         0           0               2
# 4647        162         5         91         1           3               2
# 4542        316       104         50         2           0               2
# 4535        385        89        100         2           1               2

# %%
dc[dc['cluster_labels']==3].sort_values(by=['num_reactions','num_comments','num_shares'],ascending=[True,False,False]).head()
# Out:
#      status_type  num_reactions  num_comments  num_shares  num_likes  \
# 4494       video            874          1099         541        657
# 4575       video           1012           916         396        667
# 4557       video           1228           887         408        865
# 4527       video           1290          1530         627       1032
# 4528       video           1309          1267         413       1006
#
#       num_loves  num_wows  num_hahas  num_sads  num_angrys  cluster_labels
# 4494        120        90          4         2           1               3
# 4575        220       111         13         1           0               3
# 4557        259        89          9         3           3               3
# 4527        149       106          3         0           0               3
# 4528        100       200          3         0           0               3

# %%
data.isnull().sum()
# Out:
# status_type      0
# num_reactions    0
# num_comments     0
# num_shares       0
# num_likes        0
# num_loves        0
# num_wows         0
# num_hahas        0
# num_sads         0
# num_angrys       0
# dtype: int64

# %%
dfff=pd.read_csv("/content/Live.csv")

# %%
dfff.isnull().sum()
# Out:
# status_id              0
# status_type            0
# status_published       0
# num_reactions          0
# num_comments           0
# num_shares             0
# num_likes              0
# num_loves              0
# num_wows               0
# num_hahas              0
# num_sads               0
# num_angrys             0
# Column1             7050
# Column2             7050
# Column3             7050
# Column4             7050
# dtype: int64

# %%
dfff["status_id"].nunique()
# Out:
# 6997

# %%
dfff[dfff['status_type']=='video'].count()
# Out:
# status_id           2334
# status_type         2334
# status_published    2334
# num_reactions       2334
# num_comments        2334
# num_shares          2334
# num_likes           2334
# num_loves           2334
# num_wows            2334
# num_hahas           2334
# num_sads            2334
# num_angrys          2334
# Column1                0
# Column2                0
# Column3                0
# Column4                0
# dtype: int64

# %%
de=dfff[dfff['status_type']=='photo']

# %%
de
# Out:
#                               status_id status_type status_published  \
# 1      246675545449582_1649426988507757       photo  4/21/2018 22:45
# 3      246675545449582_1648576705259452       photo   4/21/2018 2:29
# 4      246675545449582_1645700502213739       photo   4/18/2018 3:22
# 5      246675545449582_1645650162218773       photo   4/18/2018 2:14
# 8      246675545449582_1644655795651543       photo   4/17/2018 3:33
# ...                                 ...         ...              ...
# 7045  1050855161656896_1061863470556065       photo   9/24/2016 2:58
# 7046  1050855161656896_1061334757275603       photo  9/23/2016 11:19
# 7047  1050855161656896_1060126464063099       photo  9/21/2016 23:03
# 7048  1050855161656896_1058663487542730       photo   9/20/2016 0:43
# 7049  1050855161656896_1050858841656528       photo  9/10/2016 10:30
#
#       num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# ...

# %%
de[de['status_published']=='4/19/2018 22:26']
# Out:
#                             status_id status_type status_published  \
# 4592  725980084255106_850951205091326       photo  4/19/2018 22:26
#
#       num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 4592            383             5           6        379          2         2
#
#       num_hahas  num_sads  num_angrys  Column1  Column2  Column3  Column4
# 4592          0         0           0      NaN      NaN      NaN      NaN

# %%
dv=dfff[dfff["status_type"]=="video"]

# %%
dv
# Out:
#                               status_id status_type status_published  \
# 0      246675545449582_1649696485147474       video   4/22/2018 6:00
# 2      246675545449582_1648730588577397       video   4/21/2018 6:17
# 6      246675545449582_1645564175560705       video   4/18/2018 0:24
# 7      246675545449582_1644824665634656       video   4/17/2018 7:42
# 15     246675545449582_1628507150599741       video    4/1/2018 5:16
# ...                                 ...         ...              ...
# 6974  1050855161656896_1341548359254240       video   7/17/2017 8:01
# 6977  1050855161656896_1339706342771775       video  7/15/2017 10:52
# 6978  1050855161656896_1339390826136660       video   7/15/2017 4:42
# 6992  1050855161656896_1215941701814907       video    3/3/2017 9:39
# 7034  1050855161656896_1075094719232940       video  10/10/2016 1:07
#
#       num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# ...

# %%
dv[dv['status_published']=='7/15/2017 10:52']
# Out:
#                               status_id status_type status_published  \
# 6977  1050855161656896_1339706342771775       video  7/15/2017 10:52
#
#       num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 6977            253          4432         167        209         29         5
#
#       num_hahas  num_sads  num_angrys  Column1  Column2  Column3  Column4
# 6977          5         5           0      NaN      NaN      NaN      NaN

# %%
colour=['red','blue','green','yellow','cyan']
n=0

for i in range(0,len(colour)):
   plt.scatter(X[df['Clusters(5)']==i],Y[df['Clusters(5)']==i],s=10,c=colour[i])
   plt.scatter(k.cluster_centers_[:,0] ,k.cluster_centers_[:,1], color='black')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-32a387a07cc4> in <cell line: 4>()
#       3
#       4 for i in range(0,len(colour)):
# ----> 5    plt.scatter(X[df['Clusters(5)']==i],Y[df['Clusters(5)']==i],s=10,c=colour[i])
#       6    plt.scatter(k.cluster_centers_[:,0] ,k.cluster_centers_[:,1], color='black')
#
# NameError: name 'X' is not defined

# %%
dfff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7050 entries, 0 to 7049
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   status_id         7050 non-null   object
#  1   status_type       7050 non-null   object
#  2   status_published  7050 non-null   object
#  3   num_reactions     7050 non-null   int64
#  4   num_comments      7050 non-null   int64
#  5   num_shares        7050 non-null   int64
#  6   num_likes         7050 non-null   int64
#  7   num_loves         7050 non-null   int64
#  8   num_wows          7050 non-null   int64
#  9   num_hahas         7050 non-null   int64
#  10  num_sads          7050 non-null   int64
#  11  num_angrys        7050 non-null   int64
#  12  Column1           0 non-null      float64
#  13  Column2           0 non-null      float64
#  14  Column3           0 non-null      float64
#  15  Column4           0 non-null      float64
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7050 entries, 0 to 7049
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   status_type    7050 non-null   object
#  1   num_reactions  7050 non-null   int64
#  2   num_comments   7050 non-null   int64
#  3   num_shares     7050 non-null   int64
#  4   num_likes      7050 non-null   int64
#  5   num_loves      7050 non-null   int64
#  6   num_wows       7050 non-null   int64
#  7   num_hahas      7050 non-null   int64
#  8   num_sads       7050 non-null   int64
#  9   num_angrys     7050 non-null   int64
# dtypes: int64(9), object(1)
# memory usage: 550.9+ KB

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
for col in data.columns:
  if data[col].dtype=="object":
    data[col]=le.fit_transform(data[col])

# %%
data
# Out:
#       status_type  num_reactions  num_comments  num_shares  num_likes  \
# 0               3            529           512         262        432
# 1               1            150             0           0        150
# 2               3            227           236          57        204
# 3               1            111             0           0        111
# 4               1            213             0           0        204
# ...           ...            ...           ...         ...        ...
# 7045            1             89             0           0         89
# 7046            1             16             0           0         14
# 7047            1              2             0           0          1
# 7048            1            351            12          22        349
# 7049            1             17             0           0         17
#
#       num_loves  num_wows  num_hahas  num_sads  num_angrys
# 0            92         3          1         1           0
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
scaler.fit(data)
# Out:
# MinMaxScaler()

# %%
print(scaler.transform(data))
# Out:
# [[1.00000000e+00 1.12314225e-01 2.43925679e-02 ... 6.36942675e-03
#   1.96078431e-02 0.00000000e+00]
#  [3.33333333e-01 3.18471338e-02 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [1.00000000e+00 4.81953291e-02 1.12434493e-02 ... 6.36942675e-03
#   0.00000000e+00 0.00000000e+00]
#  ...
#  [3.33333333e-01 4.24628450e-04 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [3.33333333e-01 7.45222930e-02 5.71700810e-04 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [3.33333333e-01 3.60934183e-03 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]]

# %%
print(scaler.data_max_)
# Out:
# [3.000e+00 4.710e+03 2.099e+04 3.424e+03 4.710e+03 6.570e+02 2.780e+02
#  1.570e+02 5.100e+01 3.100e+01]

# %%
Data=[[5,3],[10,15],[15,12],[24,10],[30,30],[85,70],[71,80],[60,78],[70,55],[80,91]]

# %%
Data
# Out:
# [[5, 3],
#  [10, 15],
#  [15, 12],
#  [24, 10],
#  [30, 30],
#  [85, 70],
#  [71, 80],
#  [60, 78],
#  [70, 55],
#  [80, 91]]

# %%
from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import dendrogram

# %%
plt.figure(figsize=(20,10))
mergings=linkage(Data,method='complete',metric='euclidean')
dendrogram(mergings)
plt.show()

# %%
dm=pd.read_csv("/content/cars-1.csv")

# %%
dm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   model   32 non-null     object
#  1   mpg     32 non-null     float64
#  2   cyl     32 non-null     int64
#  3   disp    32 non-null     float64
#  4   hp      32 non-null     int64
#  5   drat    32 non-null     float64
#  6   wt      32 non-null     float64
#  7   qsec    32 non-null     float64
#  8   vs      32 non-null     int64
#  9   am      32 non-null     int64
#  10  gear    32 non-null     int64
#  11  carb    32 non-null     int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 3.1+ KB

# %%
car_fea=dm[['mpg','disp','hp']]

# %%
car_fea
# Out:
#      mpg   disp   hp
# 0   21.0  160.0  110
# 1   21.0  160.0  110
# 2   22.8  108.0   93
# 3   21.4  258.0  110
# 4   18.7  360.0  175
# 5   18.1  225.0  105
# 6   14.3  360.0  245
# 7   24.4  146.7   62
# 8   22.8  140.8   95
# 9   19.2  167.6  123
# 10  17.8  167.6  123
# 11  16.4  275.8  180
# 12  17.3  275.8  180
# 13  15.2  275.8  180
# 14  10.4  472.0  205
# 15  10.4  460.0  215
# 16  14.7  440.0  230
# 17  32.4   78.7   66
# 18  30.4   75.7   52
# 19  33.9   71.1   65
# 20  21.5  120.1   97
# 21  15.5  318.0  150
# 22  15.2  304.0  150
# 23  13.3  350.0  245
# 24  19.2  400.0  175
# 25  27.3   79.0   66
# 26  26.0  120.3   91
# 27  30.4   95.1  113
# 28  15.8  351.0  264
# 29  19.7  145.0  175
# 30  15.0  301.0  335
# 31  21.4  121.0  109

# %%
from sklearn.preprocessing import StandardScaler

# %%
std=StandardScaler()

# %%
scaled=std.fit_transform(car_fea)

# %%
scaled
# Out:
# array([[ 0.15329914, -0.57975032, -0.54365487],
#        [ 0.15329914, -0.57975032, -0.54365487],
#        [ 0.4567366 , -1.00602601, -0.7955699 ],
#        [ 0.22072968,  0.22361542, -0.54365487],
#        [-0.23442651,  1.05977159,  0.41954967],
#        [-0.33557233, -0.0469057 , -0.61774753],
#        [-0.97616253,  1.05977159,  1.45684686],
#        [ 0.72645879, -0.68877852, -1.25494437],
#        [ 0.4567366 , -0.73714442, -0.76593284],
#        [-0.15013833, -0.51744848, -0.35101396],
#        [-0.38614524, -0.51744848, -0.35101396],
#        [-0.62215216,  0.36953287,  0.49364233],
#        [-0.47043343,  0.36953287,  0.49364233],
#        [-0.8244438 ,  0.36953287,  0.49364233],
#        [-1.63361037,  1.97790385,  0.86410561],
#        [-1.63361037,  1.87953254,  1.01229092],
#        [-0.90873199,  1.71558035,  1.23456889],
#        [ 2.07506974, -1.24621597, -1.19567025],
#        [ 1.737917  , -1.2708088 , -1.40312969],
#        [ 2.32793429, -1.3085178 , -1.21048878],
# ...

# %%
ds=pd.DataFrame(scaled,columns=['mpg','disp','hp'])
ds.head()
# Out:
#         mpg      disp        hp
# 0  0.153299 -0.579750 -0.543655
# 1  0.153299 -0.579750 -0.543655
# 2  0.456737 -1.006026 -0.795570
# 3  0.220730  0.223615 -0.543655
# 4 -0.234427  1.059772  0.419550

# %%
from scipy.cluster.hierarchy import linkage

# %%
from scipy.cluster.hierarchy import dendrogram

# %%
from scipy.cluster.hierarchy import cut_tree

# %%
plt.figure(figsize=(20,10))
mergings=linkage(ds,method='complete',metric='euclidean')
dendrogram(mergings)
plt.show()

# %%
cluster_label=cut_tree(mergings,n_clusters=5).reshape(-1,)
cluster_label
# Out:
# array([0, 0, 0, 0, 1, 0, 2, 3, 0, 0, 0, 1, 1, 1, 4, 4, 4, 3, 3, 3, 0, 1,
#        1, 2, 1, 3, 3, 3, 2, 0, 2, 0])

# %%
dg=car_fea.copy()
dg['cluster_labels']=cluster_label
dg.head()
# Out:
#     mpg   disp   hp  cluster_labels
# 0  21.0  160.0  110               0
# 1  21.0  160.0  110               0
# 2  22.8  108.0   93               0
# 3  21.4  258.0  110               0
# 4  18.7  360.0  175               1

# %%
do=pd.read_csv("/content/customers.csv")

# %%
do
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
do.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
do.duplicated().sum()
# Out:
# 0

# %%
x=do['Age']
y=do['Spending Score (1-100)']

# %%
print(x)
# Out:
# 0      19
# 1      21
# 2      20
# 3      23
# 4      31
#        ..
# 195    35
# 196    45
# 197    32
# 198    32
# 199    30
# Name: Age, Length: 200, dtype: int64

# %%
plt.scatter(x, y, c ="pink", linewidths = 2, marker ="s", edgecolor ="green", s = 5)
plt.xlabel("age")
plt.ylabel("spending_score")
plt.show()

# %%
do.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
lee=LabelEncoder()

# %%
for col in do.columns:
  if do[col].dtype=="object":
    do[col]=lee.fit_transform(do[col])

# %%
do
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1       1   19                  15                      39
# 1             2       1   21                  15                      81
# 2             3       0   20                  16                       6
# 3             4       0   23                  16                      77
# 4             5       0   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196       0   35                 120                      79
# 196         197       0   45                 126                      28
# 197         198       1   32                 126                      74
# 198         199       1   32                 137                      18
# 199         200       1   30                 137                      83
#
# [200 rows x 5 columns]

# %%
do=do.drop(columns=['CustomerID'],axis=1)

# %%
do
# Out:
#      Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0         1   19                  15                      39
# 1         1   21                  15                      81
# 2         0   20                  16                       6
# 3         0   23                  16                      77
# 4         0   31                  17                      40
# ..      ...  ...                 ...                     ...
# 195       0   35                 120                      79
# 196       0   45                 126                      28
# 197       1   32                 126                      74
# 198       1   32                 137                      18
# 199       1   30                 137                      83
#
# [200 rows x 4 columns]

# %%
scaler=StandardScaler()
do_scaled=scaler.fit_transform(do)
do_scaled
# Out:
# array([[ 1.12815215, -1.42456879, -1.73899919, -0.43480148],
#        [ 1.12815215, -1.28103541, -1.73899919,  1.19570407],
#        [-0.88640526, -1.3528021 , -1.70082976, -1.71591298],
#        [-0.88640526, -1.13750203, -1.70082976,  1.04041783],
#        [-0.88640526, -0.56336851, -1.66266033, -0.39597992],
#        [-0.88640526, -1.20926872, -1.66266033,  1.00159627],
#        [-0.88640526, -0.27630176, -1.62449091, -1.71591298],
#        [-0.88640526, -1.13750203, -1.62449091,  1.70038436],
#        [ 1.12815215,  1.80493225, -1.58632148, -1.83237767],
#        [-0.88640526, -0.6351352 , -1.58632148,  0.84631002],
#        [ 1.12815215,  2.02023231, -1.58632148, -1.4053405 ],
#        [-0.88640526, -0.27630176, -1.58632148,  1.89449216],
#        [-0.88640526,  1.37433211, -1.54815205, -1.36651894],
#        [-0.88640526, -1.06573534, -1.54815205,  1.04041783],
#        [ 1.12815215, -0.13276838, -1.54815205, -1.44416206],
# ...

# %%
dt=pd.DataFrame(do_scaled,columns=(['Gender', 'Age', 'Annual Income (k$)', 'Spending Score (1-100)']))

# %%
dt
# Out:
#        Gender       Age  Annual Income (k$)  Spending Score (1-100)
# 0    1.128152 -1.424569           -1.738999               -0.434801
# 1    1.128152 -1.281035           -1.738999                1.195704
# 2   -0.886405 -1.352802           -1.700830               -1.715913
# 3   -0.886405 -1.137502           -1.700830                1.040418
# 4   -0.886405 -0.563369           -1.662660               -0.395980
# ..        ...       ...                 ...                     ...
# 195 -0.886405 -0.276302            2.268791                1.118061
# 196 -0.886405  0.441365            2.497807               -0.861839
# 197  1.128152 -0.491602            2.497807                0.923953
# 198  1.128152 -0.491602            2.917671               -1.250054
# 199  1.128152 -0.635135            2.917671                1.273347
#
# [200 rows x 4 columns]

# %%
plt.figure(figsize=(20,10))
mergings=linkage(dt,method='complete',metric='euclidean')
dendrogram(mergings)
plt.show()

# %%
cluster_label=cut_tree(mergings,n_clusters=5).reshape(-1,)
cluster_label
# Out:
# array([0, 1, 0, 1, 0, 1, 0, 1, 2, 1, 2, 1, 2, 1, 0, 1, 0, 1, 2, 1, 0, 1,
#        2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 0,
#        2, 1, 2, 0, 0, 0, 2, 1, 0, 2, 2, 2, 2, 2, 0, 2, 2, 1, 2, 2, 2, 1,
#        2, 2, 1, 0, 2, 2, 2, 2, 2, 1, 2, 1, 0, 2, 2, 1, 2, 2, 0, 2, 2, 0,
#        0, 2, 2, 1, 2, 0, 0, 1, 2, 0, 2, 1, 0, 2, 2, 1, 2, 0, 2, 2, 2, 2,
#        2, 0, 0, 1, 0, 0, 2, 2, 2, 2, 1, 0, 0, 3, 0, 3, 2, 3, 4, 3, 4, 3,
#        0, 3, 4, 3, 4, 3, 4, 3, 2, 3, 0, 3, 4, 3, 2, 3, 4, 3, 4, 3, 4, 3,
#        4, 3, 4, 3, 4, 3, 2, 3, 4, 3, 4, 3, 4, 3, 4, 3, 4, 3, 4, 3, 2, 3,
#        4, 3, 4, 3, 4, 3, 4, 3, 4, 3, 2, 3, 4, 3, 4, 3, 4, 3, 4, 3, 4, 3,
#        4, 3])

# %%
dtt=dt.copy()
dtt['cluster_label']=cluster_label
dtt.head()
# Out:
#      Gender       Age  Annual Income (k$)  Spending Score (1-100)  \
# 0  1.128152 -1.424569           -1.738999               -0.434801
# 1  1.128152 -1.281035           -1.738999                1.195704
# 2 -0.886405 -1.352802           -1.700830               -1.715913
# 3 -0.886405 -1.137502           -1.700830                1.040418
# 4 -0.886405 -0.563369           -1.662660               -0.395980
#
#    cluster_label
# 0              0
# 1              1
# 2              0
# 3              1
# 4              0

# %%
plt.figure(figsize=(20,15))
plt.subplot(3,1,1)
sns.scatterplot(x='Annual Income (k$)',y='Spending Score (1-100)',hue='cluster_label',data=dtt,legend='full',palette='Set1')
plt.subplot(3,1,2)
sns.scatterplot(x='Age',y='Spending Score (1-100)',hue='cluster_label',data=dtt,legend='full',palette='Set1')
plt.subplot(3,1,3)
sns.scatterplot(x='Age',y='Annual Income (k$)',hue='cluster_label',data=dtt,legend='full',palette='Set1')
# Out:
# <Axes: xlabel='Age', ylabel='Annual Income (k$)'>

# %%
wcss=[]

for k in range(1,11):
  kmeans=KMeans(n_clusters=k,init='k-means++',max_iter=300,n_init=10,random_state=10)
  kmeans.fit(dt)
  wcss.append(kmeans.inertia_)

# %%
plt.figure(figsize=(20,10))
plt.plot(range(1,11),wcss,marker='o',linestyle='-',color='r')
plt.title('elbow')
plt.grid(True)
plt.show()
